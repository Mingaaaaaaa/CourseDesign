# %%
import argparse
import math
import mindspore

from mindspore import context
from mindspore.context import ParallelMode
from mindspore.train import Model
from mindspore.train.callback import ModelCheckpoint, CheckpointConfig, LossMonitor, TimeMonitor
from mindspore.communication.management import init, get_rank, get_group_size
from mindspore.train.serialization import load_checkpoint, load_param_into_net

from mindface.detection.loss import MultiBoxLoss
from mindface.detection.datasets import create_dataset
from mindface.detection.utils import adjust_learning_rate

from mindface.detection.models import RetinaFace, RetinaFaceWithLossCell, resnet50, mobilenet025
from mindface.detection.runner import read_yaml, TrainingWrapper

# %%
#set seed
mindspore.common.seed.set_seed(42)

#set mode
context.set_context(mode=context.PYNATIVE_MODE, device_target='GPU')

# %%
# create dataset
config_cfg = 'configs/RetinaFace_mobilenet025.yaml'
cfg = read_yaml(config_cfg) #config_cfg为配置文件的地址
# change the dataset path of yours
data_dir = 'data/WiderFace/train/label.txt'
ds_train = create_dataset(data_dir, variance=[0.1,0.2], match_thresh=0.35, image_size=640, clip=False, batch_size=8,
                        repeat_num=1, shuffle=True, multiprocessing=True, num_worker=4, is_distribute=False)
print('dataset size is : \n', ds_train.get_dataset_size())
# Out:
# dataset size is :
#  1609

# %%
#set learning rate schedule
steps_per_epoch = math.ceil(ds_train.get_dataset_size())
lr = adjust_learning_rate(0.01, 0.1, (70,90), steps_per_epoch, 100,
                              warmup_epoch=5, lr_type1='dynamic_lr')

# %%
#build model
backbone_mobilenet025 = mobilenet025(1000)
retinaface_mobilenet025  = RetinaFace(phase='train', backbone=backbone_mobilenet025, in_channel=32, out_channel=64)
retinaface_mobilenet025.set_train(True)
# Out:
# RetinaFace<
#   (base): MobileNetV1<
#     (stage1): SequentialCell<
#       (0): SequentialCell<
#         (0): Conv2d<input_channels=3, output_channels=8, kernel_size=(3, 3), stride=(2, 2), pad_mode=pad, padding=1, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (1): BatchNorm2d<num_features=8, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.0.1.gamma, shape=(8,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.0.1.beta, shape=(8,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.0.1.moving_mean, shape=(8,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.0.1.moving_variance, shape=(8,), dtype=Float32, requires_grad=False)>
#         (2): LeakyReLU<>
#         >
#       (1): SequentialCell<
#         (0): Conv2d<input_channels=8, output_channels=8, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=8, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (1): BatchNorm2d<num_features=8, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.1.1.gamma, shape=(8,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.1.1.beta, shape=(8,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.1.1.moving_mean, shape=(8,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.1.1.moving_variance, shape=(8,), dtype=Float32, requires_grad=False)>
#         (2): LeakyReLU<>
#         (3): Conv2d<input_channels=8, output_channels=16, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (4): BatchNorm2d<num_features=16, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.1.4.gamma, shape=(16,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.1.4.beta, shape=(16,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.1.4.moving_mean, shape=(16,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.1.4.moving_variance, shape=(16,), dtype=Float32, requires_grad=False)>
#         (5): LeakyReLU<>
#         >
#       (2): SequentialCell<
#         (0): Conv2d<input_channels=16, output_channels=16, kernel_size=(3, 3), stride=(2, 2), pad_mode=pad, padding=1, dilation=(1, 1), group=16, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (1): BatchNorm2d<num_features=16, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.2.1.gamma, shape=(16,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.2.1.beta, shape=(16,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.2.1.moving_mean, shape=(16,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.2.1.moving_variance, shape=(16,), dtype=Float32, requires_grad=False)>
#         (2): LeakyReLU<>
#         (3): Conv2d<input_channels=16, output_channels=32, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (4): BatchNorm2d<num_features=32, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.2.4.gamma, shape=(32,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.2.4.beta, shape=(32,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.2.4.moving_mean, shape=(32,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.2.4.moving_variance, shape=(32,), dtype=Float32, requires_grad=False)>
#         (5): LeakyReLU<>
#         >
#       (3): SequentialCell<
#         (0): Conv2d<input_channels=32, output_channels=32, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=32, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (1): BatchNorm2d<num_features=32, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.3.1.gamma, shape=(32,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.3.1.beta, shape=(32,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.3.1.moving_mean, shape=(32,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.3.1.moving_variance, shape=(32,), dtype=Float32, requires_grad=False)>
#         (2): LeakyReLU<>
#         (3): Conv2d<input_channels=32, output_channels=32, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (4): BatchNorm2d<num_features=32, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.3.4.gamma, shape=(32,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.3.4.beta, shape=(32,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.3.4.moving_mean, shape=(32,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.3.4.moving_variance, shape=(32,), dtype=Float32, requires_grad=False)>
#         (5): LeakyReLU<>
#         >
#       (4): SequentialCell<
#         (0): Conv2d<input_channels=32, output_channels=32, kernel_size=(3, 3), stride=(2, 2), pad_mode=pad, padding=1, dilation=(1, 1), group=32, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (1): BatchNorm2d<num_features=32, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.4.1.gamma, shape=(32,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.4.1.beta, shape=(32,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.4.1.moving_mean, shape=(32,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.4.1.moving_variance, shape=(32,), dtype=Float32, requires_grad=False)>
#         (2): LeakyReLU<>
#         (3): Conv2d<input_channels=32, output_channels=64, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (4): BatchNorm2d<num_features=64, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.4.4.gamma, shape=(64,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.4.4.beta, shape=(64,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.4.4.moving_mean, shape=(64,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.4.4.moving_variance, shape=(64,), dtype=Float32, requires_grad=False)>
#         (5): LeakyReLU<>
#         >
#       (5): SequentialCell<
#         (0): Conv2d<input_channels=64, output_channels=64, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=64, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (1): BatchNorm2d<num_features=64, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.5.1.gamma, shape=(64,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.5.1.beta, shape=(64,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.5.1.moving_mean, shape=(64,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.5.1.moving_variance, shape=(64,), dtype=Float32, requires_grad=False)>
#         (2): LeakyReLU<>
#         (3): Conv2d<input_channels=64, output_channels=64, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (4): BatchNorm2d<num_features=64, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.5.4.gamma, shape=(64,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.5.4.beta, shape=(64,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.5.4.moving_mean, shape=(64,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.5.4.moving_variance, shape=(64,), dtype=Float32, requires_grad=False)>
#         (5): LeakyReLU<>
#         >
#       >
#     (stage2): SequentialCell<
#       (0): SequentialCell<
#         (0): Conv2d<input_channels=64, output_channels=64, kernel_size=(3, 3), stride=(2, 2), pad_mode=pad, padding=1, dilation=(1, 1), group=64, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (1): BatchNorm2d<num_features=64, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.0.1.gamma, shape=(64,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.0.1.beta, shape=(64,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.0.1.moving_mean, shape=(64,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.0.1.moving_variance, shape=(64,), dtype=Float32, requires_grad=False)>
#         (2): LeakyReLU<>
#         (3): Conv2d<input_channels=64, output_channels=128, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (4): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.0.4.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.0.4.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.0.4.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.0.4.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#         (5): LeakyReLU<>
#         >
#       (1): SequentialCell<
#         (0): Conv2d<input_channels=128, output_channels=128, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=128, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (1): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.1.1.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.1.1.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.1.1.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.1.1.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#         (2): LeakyReLU<>
#         (3): Conv2d<input_channels=128, output_channels=128, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (4): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.1.4.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.1.4.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.1.4.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.1.4.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#         (5): LeakyReLU<>
#         >
#       (2): SequentialCell<
#         (0): Conv2d<input_channels=128, output_channels=128, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=128, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (1): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.2.1.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.2.1.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.2.1.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.2.1.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#         (2): LeakyReLU<>
#         (3): Conv2d<input_channels=128, output_channels=128, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (4): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.2.4.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.2.4.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.2.4.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.2.4.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#         (5): LeakyReLU<>
#         >
#       (3): SequentialCell<
#         (0): Conv2d<input_channels=128, output_channels=128, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=128, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (1): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.3.1.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.3.1.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.3.1.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.3.1.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#         (2): LeakyReLU<>
#         (3): Conv2d<input_channels=128, output_channels=128, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (4): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.3.4.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.3.4.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.3.4.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.3.4.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#         (5): LeakyReLU<>
#         >
#       (4): SequentialCell<
#         (0): Conv2d<input_channels=128, output_channels=128, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=128, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (1): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.4.1.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.4.1.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.4.1.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.4.1.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#         (2): LeakyReLU<>
#         (3): Conv2d<input_channels=128, output_channels=128, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (4): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.4.4.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.4.4.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.4.4.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.4.4.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#         (5): LeakyReLU<>
#         >
#       (5): SequentialCell<
#         (0): Conv2d<input_channels=128, output_channels=128, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=128, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (1): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.5.1.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.5.1.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.5.1.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.5.1.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#         (2): LeakyReLU<>
#         (3): Conv2d<input_channels=128, output_channels=128, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (4): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.5.4.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.5.4.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.5.4.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.5.4.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#         (5): LeakyReLU<>
#         >
#       >
#     (stage3): SequentialCell<
#       (0): SequentialCell<
#         (0): Conv2d<input_channels=128, output_channels=128, kernel_size=(3, 3), stride=(2, 2), pad_mode=pad, padding=1, dilation=(1, 1), group=128, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (1): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage3.0.1.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage3.0.1.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage3.0.1.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage3.0.1.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#         (2): LeakyReLU<>
#         (3): Conv2d<input_channels=128, output_channels=256, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (4): BatchNorm2d<num_features=256, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage3.0.4.gamma, shape=(256,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage3.0.4.beta, shape=(256,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage3.0.4.moving_mean, shape=(256,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage3.0.4.moving_variance, shape=(256,), dtype=Float32, requires_grad=False)>
#         (5): LeakyReLU<>
#         >
#       (1): SequentialCell<
#         (0): Conv2d<input_channels=256, output_channels=256, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=256, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (1): BatchNorm2d<num_features=256, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage3.1.1.gamma, shape=(256,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage3.1.1.beta, shape=(256,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage3.1.1.moving_mean, shape=(256,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage3.1.1.moving_variance, shape=(256,), dtype=Float32, requires_grad=False)>
#         (2): LeakyReLU<>
#         (3): Conv2d<input_channels=256, output_channels=256, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#         (4): BatchNorm2d<num_features=256, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage3.1.4.gamma, shape=(256,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage3.1.4.beta, shape=(256,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage3.1.4.moving_mean, shape=(256,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage3.1.4.moving_variance, shape=(256,), dtype=Float32, requires_grad=False)>
#         (5): LeakyReLU<>
#         >
#       >
#     (fc): Dense<input_channels=256, output_channels=1000, has_bias=True>
#     >
#   (fpn): FPN<
#     (output1): ConvBNReLU<
#       (0): Conv2d<input_channels=64, output_channels=64, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=[[[[-0.03136497]]
#
#         [[ 0.11267858]]
#
#         [[ 0.05799849]]
#
#         ...
#
#         [[-0.05716274]]
#
#         [[ 0.08218437]]
#
#         [[-0.03581167]]]
#
#
#        [[[-0.05476637]]
#
#         [[ 0.01067402]]
#
#         [[-0.08976895]]
#
#         ...
#
#         [[-0.01822305]]
#
#         [[ 0.07950369]]
#
#         [[ 0.09018265]]]
#
#
#        [[[-0.12326197]]
#
#         [[ 0.00268683]]
#
#         [[-0.02064725]]
#
#         ...
#
#         [[-0.06453693]]
#
#         [[-0.10172431]]
#
#         [[ 0.09930394]]]
#
#
#        ...
#
#
#        [[[ 0.08605308]]
#
#         [[-0.00399486]]
#
#         [[ 0.00352386]]
#
#         ...
#
#         [[ 0.07184299]]
#
#         [[-0.04839179]]
#
#         [[-0.1149355 ]]]
#
#
#        [[[ 0.02208805]]
#
#         [[-0.0255789 ]]
#
#         [[ 0.11845011]]
#
#         ...
#
#         [[-0.03488137]]
#
#         [[ 0.04281771]]
#
#         [[-0.05733902]]]
#
#
#        [[[-0.10469259]]
#
#         [[ 0.12314545]]
#
#         [[-0.08594962]]
#
#         ...
#
#         [[ 0.10721489]]
#
#         [[-0.04200712]]
#
#         [[-0.00866577]]]], bias_init=zeros, format=NCHW>
#       (1): BatchNorm2d<num_features=64, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=fpn.output1.1.gamma, shape=(64,), dtype=Float32, requires_grad=True), beta=Parameter (name=fpn.output1.1.beta, shape=(64,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=fpn.output1.1.moving_mean, shape=(64,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=fpn.output1.1.moving_variance, shape=(64,), dtype=Float32, requires_grad=False)>
#       (2): LeakyReLU<>
#       >
#     (output2): ConvBNReLU<
#       (0): Conv2d<input_channels=128, output_channels=64, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=[[[[-0.08596961]]
#
#         [[-0.0739636 ]]
#
#         [[-0.04267538]]
#
#         ...
#
#         [[ 0.02008853]]
#
#         [[ 0.07034568]]
#
#         [[ 0.05478742]]]
#
#
#        [[[ 0.01469549]]
#
#         [[ 0.04069784]]
#
#         [[-0.02389624]]
#
#         ...
#
#         [[ 0.02323885]]
#
#         [[ 0.05027626]]
#
#         [[ 0.01742364]]]
#
#
#        [[[-0.01517786]]
#
#         [[ 0.08095416]]
#
#         [[ 0.00726797]]
#
#         ...
#
#         [[-0.02513566]]
#
#         [[ 0.01657823]]
#
#         [[ 0.01336316]]]
#
#
#        ...
#
#
#        [[[ 0.03566135]]
#
#         [[ 0.04531348]]
#
#         [[ 0.04949079]]
#
#         ...
#
#         [[-0.03371682]]
#
#         [[ 0.000424  ]]
#
#         [[-0.02851769]]]
#
#
#        [[[ 0.04543371]]
#
#         [[ 0.00775938]]
#
#         [[ 0.06661791]]
#
#         ...
#
#         [[-0.07466201]]
#
#         [[-0.01914584]]
#
#         [[-0.06116927]]]
#
#
#        [[[-0.02177542]]
#
#         [[ 0.0226597 ]]
#
#         [[ 0.00835048]]
#
#         ...
#
#         [[ 0.04686554]]
#
#         [[ 0.04667128]]
#
#         [[-0.03669081]]]], bias_init=zeros, format=NCHW>
#       (1): BatchNorm2d<num_features=64, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=fpn.output2.1.gamma, shape=(64,), dtype=Float32, requires_grad=True), beta=Parameter (name=fpn.output2.1.beta, shape=(64,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=fpn.output2.1.moving_mean, shape=(64,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=fpn.output2.1.moving_variance, shape=(64,), dtype=Float32, requires_grad=False)>
#       (2): LeakyReLU<>
#       >
#     (output3): ConvBNReLU<
#       (0): Conv2d<input_channels=256, output_channels=64, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=[[[[-5.2326210e-02]]
#
#         [[-6.1070915e-02]]
#
#         [[-9.0686837e-03]]
#
#         ...
#
#         [[-9.2310561e-03]]
#
#         [[ 5.5730551e-02]]
#
#         [[-3.5283871e-02]]]
#
#
#        [[[-3.0407300e-02]]
#
#         [[-4.9888901e-02]]
#
#         [[ 1.3196284e-02]]
#
#         ...
#
#         [[-2.3686090e-03]]
#
#         [[ 2.1753272e-02]]
#
#         [[-8.1269778e-03]]]
#
#
#        [[[ 7.3404261e-03]]
#
#         [[-5.5244207e-02]]
#
#         [[ 2.4532935e-02]]
#
#         ...
#
#         [[ 9.9025043e-03]]
#
#         [[-5.7216376e-02]]
#
#         [[ 1.0844350e-02]]]
#
#
#        ...
#
#
#        [[[-4.3425657e-02]]
#
#         [[-3.8487352e-02]]
#
#         [[-4.9192026e-02]]
#
#         ...
#
#         [[ 2.8171927e-02]]
#
#         [[-3.2864824e-02]]
#
#         [[-4.5275830e-02]]]
#
#
#        [[[-7.1550377e-05]]
#
#         [[ 3.7845660e-02]]
#
#         [[-2.7652157e-02]]
#
#         ...
#
#         [[ 2.4169356e-02]]
#
#         [[-2.8425869e-02]]
#
#         [[-5.4952670e-03]]]
#
#
#        [[[-2.5357673e-02]]
#
#         [[-4.3747220e-02]]
#
#         [[-2.6102742e-02]]
#
#         ...
#
#         [[ 9.9505363e-03]]
#
#         [[-5.2094907e-02]]
#
#         [[-3.5263367e-02]]]], bias_init=zeros, format=NCHW>
#       (1): BatchNorm2d<num_features=64, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=fpn.output3.1.gamma, shape=(64,), dtype=Float32, requires_grad=True), beta=Parameter (name=fpn.output3.1.beta, shape=(64,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=fpn.output3.1.moving_mean, shape=(64,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=fpn.output3.1.moving_variance, shape=(64,), dtype=Float32, requires_grad=False)>
#       (2): LeakyReLU<>
#       >
#     (merge1): ConvBNReLU<
#       (0): Conv2d<input_channels=64, output_channels=64, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=1, has_bias=False, weight_init=[[[[ 2.19430327e-02 -1.64500792e-02  4.04805057e-02]
#          [ 6.80869271e-05  1.37827708e-03 -3.86404395e-02]
#          [ 3.80438976e-02 -2.71472130e-02  3.19504994e-03]]
#
#         [[-8.69378261e-03 -7.03460816e-03  1.19416807e-02]
#          [ 1.35073895e-02 -2.88092829e-02 -3.44455730e-05]
#          [ 2.42064539e-02 -4.72612632e-03 -2.78496277e-02]]
#
#         [[-1.55652547e-02 -2.39683688e-02 -3.11818775e-02]
#
#         [[ 0.06924903]]
#
#         [[-0.11256084]]
#
#         [[-0.12333495]]
#
#         [[ 0.02714737]]
#
#         [[-0.07264558]]
#
#         [[ 0.09402182]]
#
#         [[-0.11279848]]
#
#         [[-0.05023615]]
#
#         [[-0.03883934]]
#
#         [[ 0.05859067]]
#
#         [[ 0.07439712]]
#
#         [[-0.01911326]]
#
#         [[-0.08250178]]
#
#         [[-0.01628137]]
#
#         [[ 0.08793717]]
#
#         [[-0.09520677]]
#
#         [[-0.10148951]]
#
#         [[ 0.12380376]]
#
#         [[-0.06227851]]
#
#         [[ 0.06679644]]
#
#         [[-0.00519203]]
#
#         [[ 0.07569028]]
#
#         [[ 0.07585616]]
#
#         [[-0.09421344]]
#
#         [[ 0.08623015]]
#
#         [[-0.08204706]]
#
#         [[-0.0429308 ]]
#
#         [[-0.06980095]]
#
#         [[ 0.04420141]]
#
#         [[ 0.0817095 ]]
#
#         [[ 0.06936719]]
#
#         [[-0.07014714]]
#
#         [[-0.05248079]]
#
#         [[-0.07710453]]
#
#         [[ 0.00585482]]
#
#         [[ 0.01121785]]
#
#         [[ 0.01686387]]
#
#         [[-0.00145662]]
#
#         [[ 0.08031971]]
#
#         [[-0.03996474]]
#
#         [[-0.02297628]]
#
#         [[ 0.03030403]]
#
#         [[-0.04539018]]
#
#         [[-0.0340191 ]]
#
#         [[ 0.03518022]]
#
#         [[ 0.01724386]]
#
#         [[ 0.00445887]]
#
#         [[-0.1058204 ]]
#
#         [[ 0.04511803]]
#
#         [[ 0.08935475]]
#
#         [[ 0.11653739]]
#
#         [[ 0.09478663]]
#
#         [[-0.10536855]]
#
#         [[ 0.11744066]]
#
#         [[-0.10232897]]
#
#         [[ 0.06474099]]
#
#         [[-0.1060617 ]]
#
#         [[-0.09939149]]
#
#         [[-0.06492057]]
#
#         [[ 0.00267387]]
#
#         [[-0.0445064 ]]
#
#         [[ 0.0583714 ]]
#
#         [[ 0.06114475]]]
#
#
#        [[[ 0.01844568]]
#
#         [[-0.04762572]]
#
#         [[-0.10535819]]
#
#         [[ 0.02862959]]
#
#         [[-0.11218687]]
#
#         [[-0.00499573]]
#
#         [[-0.01142291]]
#
#         [[ 0.10565849]]
#
#         [[ 0.07277714]]
#
#         [[ 0.07578942]]
#
#         [[-0.11904074]]
#
#         [[ 0.06236868]]
#
#         [[-0.05500098]]
#
#         [[-0.05494277]]
#
#         [[-0.10638485]]
#
#         [[-0.10220741]]
#
#         [[-0.03169647]]
#
#         [[ 0.12281895]]
#
#         [[-0.03768089]]
#
#         [[-0.10389006]]
#
#         [[ 0.01294029]]
#
#         [[ 0.06926396]]
#
#         [[ 0.06040155]]
#
#         [[ 0.10206677]]
#
#         [[ 0.00399695]]
#
#         [[ 0.08732527]]
#
#         [[-0.11620615]]
#
#         [[ 0.10130894]]
#
#         [[-0.07338422]]
#
#         [[-0.09231371]]
#
#         [[ 0.09872713]]
#
#         [[-0.10682948]]
#
#         [[ 0.02677983]]
#
#         [[ 0.01100681]]
#
#         [[-0.12132595]]
#
#         [[ 0.06087784]]
#
#         [[-0.04363855]]
#
#         [[-0.11421496]]
#
#         [[-0.10303507]]
#
#         [[-0.05380174]]
#
#         [[ 0.03986758]]
#
#         [[ 0.05901287]]
#
#         [[ 0.09853642]]
#
#         [[ 0.01165175]]
#
#         [[-0.02254462]]
#
#         [[ 0.09492424]]
#
#         [[-0.02797688]]
#
#         [[-0.00570773]]
#
#         [[-0.02367667]]
#
#         [[ 0.04733118]]
#
#         [[ 0.0501971 ]]
#
#         [[ 0.01347846]]
#
#         [[ 0.03563077]]
#
#         [[-0.09113088]]
#
#         [[ 0.07627052]]
#
#         [[ 0.06175433]]
#
#         [[-0.10163226]]
#
#         [[ 0.02197796]]
#
#         [[-0.05042969]]
#
#         [[ 0.05667137]]
#
#         [[ 0.11937606]]
#
#         [[-0.10405646]]
#
#         [[ 0.0356474 ]]
#
#         [[ 0.07789201]]]
#
#
#        [[[-0.07342738]]
#
#         [[-0.07658599]]
#
#         [[ 0.01184597]]
#
#         [[-0.0818024 ]]
#
#         [[-0.01953278]]
#
#         [[-0.0276658 ]]
#
#         [[-0.00653234]]
#
#         [[ 0.08799778]]
#
#         [[ 0.1057347 ]]
#
#         [[ 0.09491479]]
#
#         [[-0.04746303]]
#
#         [[ 0.06431379]]
#
#         [[-0.03206751]]
#
#         [[ 0.10771161]]
#
#         [[-0.04770182]]
#
#         [[-0.07511391]]
#
#         [[ 0.08228513]]
#
#         [[-0.05129223]]
#
#         [[ 0.03876377]]
#
#         [[ 0.00450003]]
#
#         [[-0.07658106]]
#
#         [[ 0.04901382]]
#
#         [[ 0.02313844]]
#
#         [[-0.01868447]]
#
#         [[ 0.00211985]]
#
#         [[-0.11403055]]
#
#         [[-0.00938006]]
#
#         [[-0.08440918]]
#
#         [[-0.12498783]]
#
#         [[-0.07998161]]
#
#         [[ 0.01477067]]
#
#         [[ 0.00541093]]
#
#         [[-0.08859876]]
#
#         [[-0.123407  ]]
#
#         [[-0.02743082]]
#
#         [[-0.08168336]]
#
#         [[ 0.02379277]]
#
#         [[-0.00198291]]
#
#         [[ 0.03437313]]
#
#         [[-0.06697703]]
#
#         [[ 0.06273629]]
#
#         [[-0.11884708]]
#
#         [[-0.01449374]]
#
#         [[-0.01806301]]
#
#         [[ 0.10784499]]
#
#         [[ 0.02871769]]
#
#         [[ 0.09380561]]
#
#         [[ 0.03666148]]
#
#         [[-0.02335553]]
#
#         [[ 0.10300087]]
#
#         [[ 0.10727682]]
#
#         [[ 0.11906265]]
#
#         [[-0.0369576 ]]
#
#         [[-0.10238626]]
#
#         [[-0.09713667]]
#
#         [[-0.0176633 ]]
#
#         [[-0.09049416]]
#
#         [[ 0.10603427]]
#
#         [[-0.06044694]]
#
#         [[ 0.05657554]]
#
#         [[ 0.00643751]]
#
#         [[ 0.1034174 ]]
#
#         [[ 0.01687668]]
#
#         [[ 0.12128118]]]
#
#
#        [[[-0.10465018]]
#
#         [[ 0.04137226]]
#
#         [[ 0.02871008]]
#
#         [[ 0.04408861]]
#
#         [[-0.04569753]]
#
#         [[-0.10286768]]
#
#         [[-0.07143368]]
#
#         [[ 0.09029781]]
#
#         [[ 0.08220701]]
#
#         [[-0.06909885]]
#
#         [[-0.11788401]]
#
#         [[ 0.0408827 ]]
#
#         [[-0.07008236]]
#
#         [[-0.00172753]]
#
#         [[-0.01523919]]
#
#         [[ 0.04108904]]
#
#         [[-0.03706225]]
#
#         [[-0.01572955]]
#
#         [[ 0.08232275]]
#
#         [[-0.04651045]]
#
#         [[-0.07828254]]
#
#         [[-0.02915381]]
#
#         [[-0.05922602]]
#
#         [[ 0.10106028]]
#
#         [[-0.12230319]]
#
#         [[ 0.08114323]]
#
#         [[-0.06424982]]
#
#         [[-0.05692493]]
#
#         [[-0.09799464]]
#
#         [[ 0.00535691]]
#
#         [[-0.11359742]]
#
#         [[-0.01580256]]
#
#         [[ 0.05823968]]
#
#         [[ 0.05443152]]
#
#         [[-0.09196038]]
#
#         [[-0.04030427]]
#
#         [[ 0.07214313]]
#
#         [[-0.08881977]]
#
#         [[-0.07181456]]
#
#         [[-0.07838824]]
#
#         [[ 0.10646826]]
#
#         [[-0.11694592]]
#
#         [[-0.09755758]]
#
#         [[ 0.12196326]]
#
#         [[ 0.05485645]]
#
#         [[ 0.05243072]]
#
#         [[-0.05411016]]
#
#         [[ 0.03347715]]
#
#         [[-0.00971213]]
#
#         [[-0.04437888]]
#
#         [[-0.10741735]]
#
#         [[ 0.12399153]]
#
#         [[-0.10672759]]
#
#         [[ 0.0042752 ]]
#
#         [[ 0.00257857]]
#
#         [[ 0.05740612]]
#
#         [[-0.08013073]]
#
#         [[ 0.09356421]]
#
#         [[ 0.07167282]]
#
#         [[ 0.02039733]]
#
#         [[ 0.027545  ]]
#
#         [[-0.03854016]]
#
#         [[-0.10372098]]
#
#         [[-0.07012505]]]
#
#
#        [[[ 0.05768338]]
#
#         [[-0.11840018]]
#
#         [[-0.09258994]]
#
#         [[ 0.09258158]]
#
#         [[ 0.08054789]]
#
#         [[ 0.07365398]]
#
#         [[ 0.0104652 ]]
#
#         [[ 0.07826498]]
#
#         [[ 0.01287376]]
#
#         [[-0.01546954]]
#
#         [[ 0.11777766]]
#
#         [[ 0.12005596]]
#
#         [[-0.06999076]]
#
#         [[-0.05595121]]
#
#         [[-0.05488281]]
#
#         [[-0.12002736]]
#
#         [[ 0.04106962]]
#
#         [[ 0.0607038 ]]
#
#         [[-0.09460468]]
#
#         [[ 0.09973408]]
#
#         [[-0.0842943 ]]
#
#         [[ 0.03482461]]
#
#         [[ 0.07937609]]
#
#         [[-0.00370865]]
#
#         [[-0.07366523]]
#
#         [[-0.11131665]]
#
#         [[ 0.01804877]]
#
#         [[-0.02721989]]
#
#         [[-0.10135803]]
#
#         [[ 0.08941694]]
#
#         [[-0.11640904]]
#
#         [[ 0.069507  ]]
#
#         [[ 0.06711199]]
#
#         [[-0.12419552]]
#
#         [[-0.08869303]]
#
#         [[ 0.04693426]]
#
#         [[-0.01244352]]
#
#         [[ 0.02194765]]
#
#         [[-0.05560708]]
#
#         [[-0.06323257]]
#
#         [[ 0.01616281]]
#
#         [[-0.04649884]]
#
#         [[-0.12293606]]
#
#         [[-0.06191086]]
#
#         [[-0.06508635]]
#
#         [[-0.05921249]]
#
#         [[ 0.05368768]]
#
#         [[-0.10796905]]
#
#         [[-0.11485462]]
#
#         [[-0.01496728]]
#
#         [[-0.02947919]]
#
#         [[ 0.07259478]]
#
#         [[ 0.08447067]]
#
#         [[-0.00867409]]
#
#         [[-0.0727896 ]]
#
#         [[-0.05175861]]
#
#         [[ 0.06675438]]
#
#         [[-0.09795051]]
#
#         [[-0.00234696]]
#
#         [[ 0.10263179]]
#
#         [[-0.07507818]]
#
#         [[-0.12366974]]
#
#         [[-0.00342081]]
#
#         [[-0.04088119]]]], bias_init=[ 0.05382174  0.08447228 -0.06534094 -0.04706277 -0.11848809  0.02794306
#         0.01602952 -0.00290283], format=NCHW>
#       >
#     >
#   (landmarkhead): CellList<
#     (0): LandmarkHead<
#       (conv1x1): Conv2d<input_channels=64, output_channels=20, kernel_size=(1, 1), stride=(1, 1), pad_mode=same, padding=0, dilation=(1, 1), group=1, has_bias=True, weight_init=[[[[-0.0653588 ]]
#
#         [[ 0.02325419]]
#
#         [[ 0.02899218]]
#
#         ...
#
#         [[-0.00811465]]
#
#         [[-0.05752086]]
#
#         [[-0.11302832]]]
#
#
#        [[[-0.07252625]]
#
#         [[-0.10044938]]
#
#         [[ 0.09326287]]
#
#         ...
#
#         [[-0.11281712]]
#
#         [[-0.08194516]]
#
#         [[-0.03124272]]]
#
#
#        [[[-0.11106289]]
#
#         [[-0.09137164]]
#
#         [[ 0.07008419]]
#
#         ...
#
#         [[-0.00427137]]
#
#         [[-0.01607775]]
#
#         [[-0.05605372]]]
#
#
#        ...
#
#
#        [[[-0.01259071]]
#
#         [[ 0.0029925 ]]
#
#         [[ 0.11023385]]
#
#         ...
#
#         [[-0.02408899]]
#
#         [[ 0.0912229 ]]
#
#         [[ 0.05574048]]]
#
#
#        [[[ 0.05445006]]
#
#         [[ 0.07536841]]
#
#         [[-0.10625771]]
#
#         ...
#
#         [[-0.0211121 ]]
#
#         [[ 0.12216372]]
#
#         [[-0.04837928]]]
#
#
#        [[[ 0.07165819]]
#
#         [[-0.02592759]]
#
#         [[ 0.03647464]]
#
#         ...
#
#         [[-0.0245426 ]]
#
#         [[-0.04654476]]
#
#         [[ 0.01613258]]]], bias_init=[ 0.05414535 -0.02863894  0.11415346  0.03286158 -0.09530407  0.09206541
#         0.04017619 -0.02611531  0.08966954  0.01639848 -0.06596173 -0.07224327
#         0.07476466  0.02277052  0.10175966 -0.08947156 -0.08445574  0.06374609
#        -0.01066985 -0.10125124], format=NCHW>
#       >
#     (1): LandmarkHead<
#       (conv1x1): Conv2d<input_channels=64, output_channels=20, kernel_size=(1, 1), stride=(1, 1), pad_mode=same, padding=0, dilation=(1, 1), group=1, has_bias=True, weight_init=[[[[ 0.00358068]]
#
#         [[ 0.12426128]]
#
#         [[-0.06585716]]
#
#         ...
#
#         [[-0.09734076]]
#
#         [[-0.04321113]]
#
#         [[-0.00961618]]]
#
#
#        [[[-0.10277773]]
#
#         [[-0.09220212]]
#
#         [[-0.11758328]]
#
#         ...
#
#         [[-0.08050378]]
#
#         [[-0.08951245]]
#
#         [[-0.12063331]]]
#
#
#        [[[-0.0449147 ]]
#
#         [[ 0.03370849]]
#
#         [[-0.07513755]]
#
#         ...
#
#         [[-0.01857302]]
#
#         [[-0.1007526 ]]
#
#         [[ 0.12078415]]]
#
#
#        ...
#
#
#        [[[-0.0597114 ]]
#
#         [[ 0.0085814 ]]
#
#         [[ 0.10340444]]
#
#         ...
#
#         [[-0.02819916]]
#
#         [[-0.12492356]]
#
#         [[-0.08493023]]]
#
#
#        [[[ 0.10049584]]
#
#         [[ 0.08459831]]
#
#         [[ 0.10932685]]
#
#         ...
#
#         [[ 0.11419805]]
#
#         [[-0.07410893]]
#
#         [[-0.05809066]]]
#
#
#        [[[-0.11180259]]
#
#         [[-0.01826129]]
#
#         [[-0.0381434 ]]
#
#         ...
#
#         [[-0.08247306]]
#
#         [[-0.0014336 ]]
#
#         [[-0.03655935]]]], bias_init=[-0.12344098 -0.04067947 -0.0036378  -0.07383668 -0.06831656 -0.09884556
#        -0.05301439  0.03157887  0.05649547  0.10945679  0.08885825 -0.09810432
#         0.06184784  0.00966601  0.01002616 -0.04747055 -0.00793113  0.0543037
#         0.06566436 -0.01242254], format=NCHW>
#       >
#     (2): LandmarkHead<
#       (conv1x1): Conv2d<input_channels=64, output_channels=20, kernel_size=(1, 1), stride=(1, 1), pad_mode=same, padding=0, dilation=(1, 1), group=1, has_bias=True, weight_init=[[[[ 0.0513016 ]]
#
#         [[ 0.05233982]]
#
#         [[ 0.10302562]]
#
#         ...
#
#         [[ 0.01446032]]
#
#         [[-0.04745722]]
#
#         [[-0.02093972]]]
#
#
#        [[[-0.08234599]]
#
#         [[-0.0007145 ]]
#
#         [[ 0.09202049]]
#
#         ...
#
#         [[ 0.04523911]]
#
#         [[-0.09334278]]
#
#         [[-0.00420657]]]
#
#
#        [[[-0.07493368]]
#
#         [[-0.10226868]]
#
#         [[ 0.03668706]]
#
#         ...
#
#         [[ 0.09010993]]
#
#         [[ 0.00208953]]
#
#         [[-0.03266313]]]
#
#
#        ...
#
#
#        [[[ 0.10775886]]
#
#         [[ 0.05248325]]
#
#         [[ 0.05735843]]
#
#         ...
#
#         [[ 0.01156745]]
#
#         [[ 0.08356827]]
#
#         [[ 0.08953626]]]
#
#
#        [[[ 0.0153541 ]]
#
#         [[-0.00473282]]
#
#         [[ 0.01701587]]
#
#         ...
#
#         [[-0.1131289 ]]
#
#         [[ 0.08883651]]
#
#         [[-0.09303115]]]
#
#
#        [[[ 0.11693742]]
#
#         [[-0.01664815]]
#
#         [[ 0.05949557]]
#
#         ...
#
#         [[ 0.09185981]]
#
#         [[ 0.07541189]]
#
#         [[ 0.11810076]]]], bias_init=[ 0.09505635 -0.00851724 -0.1151537  -0.03611372 -0.0938806   0.07582618
#         0.08996104 -0.02302789 -0.09152261  0.06597113 -0.03550252  0.00417393
#        -0.12098659  0.07715964  0.11603611  0.01638712 -0.07495493  0.02297291
#         0.1072472  -0.03611465], format=NCHW>
#       >
#     >
#   >

# %%
# load checkpoint
pretrain_model_path = 'pretrained/RetinaFace_MobileNet025.ckpt'
param_dict_retinaface = load_checkpoint(pretrain_model_path)
load_param_into_net(retinaface_mobilenet025, param_dict_retinaface)
print(f'Resume Model from [{pretrain_model_path}] Done.')
# Out:
# [WARNING] ME(8443:140174223581376,MainProcess):2024-04-18-00:23:34.219.023 [mindspore/train/serialization.py:734] For 'load_param_into_net', remove parameter prefix name: network., continue to load.
# Resume Model from [pretrained/RetinaFace_MobileNet025.ckpt] Done.

# %%
# set loss
multibox_loss = MultiBoxLoss(num_classes = 2, num_boxes = 16800, neg_pre_positive=7)

# %%
# set optimazer
opt = mindspore.nn.SGD(params=retinaface_mobilenet025.trainable_params(), learning_rate=lr, momentum=0.9,
                               weight_decay=5e-4, loss_scale=1)

# %%
# add loss and optimazer  
net = RetinaFaceWithLossCell(retinaface_mobilenet025, multibox_loss, loc_weight=2.0, class_weight=1.0, landm_weight=1.0)
net = TrainingWrapper(net, opt)

# %%
finetune_epochs = 10
model = Model(net)
config_ck = CheckpointConfig(save_checkpoint_steps=1000,
                                 keep_checkpoint_max=3)
ckpoint_cb = ModelCheckpoint(prefix="RetinaFace", directory=cfg['ckpt_path'], config=config_ck)

time_cb = TimeMonitor(data_size=ds_train.get_dataset_size())
callback_list = [LossMonitor(), time_cb, ckpoint_cb]

print("============== Starting Training ==============")
model.train(finetune_epochs, ds_train, callbacks=callback_list, dataset_sink_mode=False)
# Out:
# ============== Starting Training ==============
# [WARNING] MD(4761,7f7bbe8b6700,python):2024-04-18-00:17:11.683.743 [mindspore/ccsrc/minddata/dataset/engine/datasetops/source/generator_op.cc:195] operator()] Bad performance attention, it takes more than 25 seconds to generator.__next__ new row, which might cause `GetNext` timeout problem when sink_mode=True. You can increase the parameter num_parallel_workers in GeneratorDataset / optimize the efficiency of obtaining samples in the user-defined generator function.
# epoch: 1 step: 1, loss is 3.9023001194000244
# epoch: 1 step: 2, loss is 5.1197357177734375
# epoch: 1 step: 3, loss is 2.216236114501953
# epoch: 1 step: 4, loss is 4.17732048034668
# epoch: 1 step: 5, loss is 2.1989660263061523
# epoch: 1 step: 6, loss is 2.4191744327545166
# epoch: 1 step: 7, loss is 4.706803798675537
# epoch: 1 step: 8, loss is 3.6719870567321777
# epoch: 1 step: 9, loss is 6.679204940795898
# epoch: 1 step: 10, loss is 2.627380132675171
# epoch: 1 step: 11, loss is 3.092747688293457
# epoch: 1 step: 12, loss is 2.8383612632751465
# epoch: 1 step: 13, loss is 2.9648098945617676
# epoch: 1 step: 14, loss is 3.2772698402404785
# epoch: 1 step: 15, loss is 5.015932083129883
# epoch: 1 step: 16, loss is 5.855517387390137
# epoch: 1 step: 17, loss is 4.99378776550293
# epoch: 1 step: 18, loss is 5.658236503601074
# epoch: 1 step: 19, loss is 3.9252257347106934
# epoch: 1 step: 20, loss is 3.6157286167144775
# epoch: 1 step: 21, loss is 6.473025321960449
# epoch: 1 step: 22, loss is 8.208998680114746
# epoch: 1 step: 23, loss is 6.426080703735352
# epoch: 1 step: 24, loss is 3.6377151012420654
# epoch: 1 step: 25, loss is 4.050309658050537
# epoch: 1 step: 26, loss is 7.17209529876709
# epoch: 1 step: 27, loss is 4.4931864738464355
# epoch: 1 step: 28, loss is 2.3871936798095703
# epoch: 1 step: 29, loss is 2.9519290924072266
# epoch: 1 step: 30, loss is 2.478379726409912
# epoch: 1 step: 31, loss is 3.004310131072998
# epoch: 1 step: 276, loss is 5.620757102966309
# epoch: 1 step: 277, loss is 4.537490367889404
# epoch: 1 step: 278, loss is 6.376957893371582
# epoch: 1 step: 279, loss is 3.681988477706909
# epoch: 1 step: 280, loss is 4.935281753540039
# epoch: 1 step: 281, loss is 5.3919548988342285
# epoch: 1 step: 282, loss is 3.3249568939208984
# epoch: 1 step: 283, loss is 1.8786468505859375
# epoch: 1 step: 284, loss is 3.059612274169922
# epoch: 1 step: 285, loss is 5.101179122924805
# epoch: 1 step: 286, loss is 5.85420560836792
# epoch: 1 step: 287, loss is 10.803406715393066
# epoch: 1 step: 288, loss is 7.033509731292725
# epoch: 1 step: 289, loss is 5.368712902069092
# epoch: 1 step: 290, loss is 2.3808836936950684
# epoch: 1 step: 291, loss is 6.070647239685059
# epoch: 1 step: 292, loss is 3.886995792388916
# epoch: 1 step: 293, loss is 7.266635894775391
# epoch: 1 step: 294, loss is 3.019296646118164
# epoch: 1 step: 295, loss is 3.3409056663513184
# epoch: 1 step: 296, loss is 5.255505561828613
# epoch: 1 step: 297, loss is 4.176544666290283
# epoch: 1 step: 298, loss is 2.4759418964385986
# epoch: 1 step: 299, loss is 5.258351802825928
# epoch: 1 step: 300, loss is 6.8932952880859375
# epoch: 1 step: 301, loss is 4.575308322906494
# epoch: 1 step: 302, loss is 4.407852649688721
# epoch: 1 step: 303, loss is 6.06165885925293
# epoch: 1 step: 304, loss is 2.609311580657959
# epoch: 1 step: 305, loss is 4.109521389007568
# epoch: 1 step: 306, loss is 5.197432994842529
# epoch: 1 step: 307, loss is 9.21425724029541
# epoch: 1 step: 308, loss is 6.18779182434082
# epoch: 1 step: 309, loss is 4.40176248550415
# epoch: 1 step: 310, loss is 4.325507640838623
# epoch: 1 step: 311, loss is 7.093569755554199
# epoch: 1 step: 312, loss is 4.713769912719727

# %% [markdown]
# 看起来这个loss也没啥好训练的，直接开始下面验证一下效果吧

# %%
network = RetinaFace(phase='predict', backbone=backbone_mobilenet025, in_channel=32, out_channel=64)
backbone_mobilenet025.set_train(False)
net.set_train(False)
# Out:
# TrainingWrapper<
#   (network): RetinaFaceWithLossCell<
#     (network): RetinaFace<
#       (base): MobileNetV1<
#         (stage1): SequentialCell<
#           (0): SequentialCell<
#             (0): Conv2d<input_channels=3, output_channels=8, kernel_size=(3, 3), stride=(2, 2), pad_mode=pad, padding=1, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (1): BatchNorm2d<num_features=8, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.0.1.gamma, shape=(8,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.0.1.beta, shape=(8,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.0.1.moving_mean, shape=(8,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.0.1.moving_variance, shape=(8,), dtype=Float32, requires_grad=False)>
#             (2): LeakyReLU<>
#             >
#           (1): SequentialCell<
#             (0): Conv2d<input_channels=8, output_channels=8, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=8, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (1): BatchNorm2d<num_features=8, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.1.1.gamma, shape=(8,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.1.1.beta, shape=(8,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.1.1.moving_mean, shape=(8,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.1.1.moving_variance, shape=(8,), dtype=Float32, requires_grad=False)>
#             (2): LeakyReLU<>
#             (3): Conv2d<input_channels=8, output_channels=16, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (4): BatchNorm2d<num_features=16, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.1.4.gamma, shape=(16,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.1.4.beta, shape=(16,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.1.4.moving_mean, shape=(16,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.1.4.moving_variance, shape=(16,), dtype=Float32, requires_grad=False)>
#             (5): LeakyReLU<>
#             >
#           (2): SequentialCell<
#             (0): Conv2d<input_channels=16, output_channels=16, kernel_size=(3, 3), stride=(2, 2), pad_mode=pad, padding=1, dilation=(1, 1), group=16, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (1): BatchNorm2d<num_features=16, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.2.1.gamma, shape=(16,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.2.1.beta, shape=(16,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.2.1.moving_mean, shape=(16,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.2.1.moving_variance, shape=(16,), dtype=Float32, requires_grad=False)>
#             (2): LeakyReLU<>
#             (3): Conv2d<input_channels=16, output_channels=32, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (4): BatchNorm2d<num_features=32, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.2.4.gamma, shape=(32,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.2.4.beta, shape=(32,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.2.4.moving_mean, shape=(32,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.2.4.moving_variance, shape=(32,), dtype=Float32, requires_grad=False)>
#             (5): LeakyReLU<>
#             >
#           (3): SequentialCell<
#             (0): Conv2d<input_channels=32, output_channels=32, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=32, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (1): BatchNorm2d<num_features=32, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.3.1.gamma, shape=(32,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.3.1.beta, shape=(32,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.3.1.moving_mean, shape=(32,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.3.1.moving_variance, shape=(32,), dtype=Float32, requires_grad=False)>
#             (2): LeakyReLU<>
#             (3): Conv2d<input_channels=32, output_channels=32, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (4): BatchNorm2d<num_features=32, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.3.4.gamma, shape=(32,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.3.4.beta, shape=(32,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.3.4.moving_mean, shape=(32,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.3.4.moving_variance, shape=(32,), dtype=Float32, requires_grad=False)>
#             (5): LeakyReLU<>
#             >
#           (4): SequentialCell<
#             (0): Conv2d<input_channels=32, output_channels=32, kernel_size=(3, 3), stride=(2, 2), pad_mode=pad, padding=1, dilation=(1, 1), group=32, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (1): BatchNorm2d<num_features=32, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.4.1.gamma, shape=(32,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.4.1.beta, shape=(32,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.4.1.moving_mean, shape=(32,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.4.1.moving_variance, shape=(32,), dtype=Float32, requires_grad=False)>
#             (2): LeakyReLU<>
#             (3): Conv2d<input_channels=32, output_channels=64, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (4): BatchNorm2d<num_features=64, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.4.4.gamma, shape=(64,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.4.4.beta, shape=(64,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.4.4.moving_mean, shape=(64,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.4.4.moving_variance, shape=(64,), dtype=Float32, requires_grad=False)>
#             (5): LeakyReLU<>
#             >
#           (5): SequentialCell<
#             (0): Conv2d<input_channels=64, output_channels=64, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=64, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (1): BatchNorm2d<num_features=64, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.5.1.gamma, shape=(64,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.5.1.beta, shape=(64,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.5.1.moving_mean, shape=(64,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.5.1.moving_variance, shape=(64,), dtype=Float32, requires_grad=False)>
#             (2): LeakyReLU<>
#             (3): Conv2d<input_channels=64, output_channels=64, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (4): BatchNorm2d<num_features=64, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage1.5.4.gamma, shape=(64,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage1.5.4.beta, shape=(64,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage1.5.4.moving_mean, shape=(64,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage1.5.4.moving_variance, shape=(64,), dtype=Float32, requires_grad=False)>
#             (5): LeakyReLU<>
#             >
#           >
#         (stage2): SequentialCell<
#           (0): SequentialCell<
#             (0): Conv2d<input_channels=64, output_channels=64, kernel_size=(3, 3), stride=(2, 2), pad_mode=pad, padding=1, dilation=(1, 1), group=64, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (1): BatchNorm2d<num_features=64, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.0.1.gamma, shape=(64,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.0.1.beta, shape=(64,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.0.1.moving_mean, shape=(64,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.0.1.moving_variance, shape=(64,), dtype=Float32, requires_grad=False)>
#             (2): LeakyReLU<>
#             (3): Conv2d<input_channels=64, output_channels=128, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (4): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.0.4.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.0.4.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.0.4.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.0.4.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#             (5): LeakyReLU<>
#             >
#           (1): SequentialCell<
#             (0): Conv2d<input_channels=128, output_channels=128, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=128, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (1): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.1.1.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.1.1.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.1.1.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.1.1.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#             (2): LeakyReLU<>
#             (3): Conv2d<input_channels=128, output_channels=128, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (4): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.1.4.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.1.4.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.1.4.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.1.4.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#             (5): LeakyReLU<>
#             >
#           (2): SequentialCell<
#             (0): Conv2d<input_channels=128, output_channels=128, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=128, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (1): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.2.1.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.2.1.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.2.1.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.2.1.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#             (2): LeakyReLU<>
#             (3): Conv2d<input_channels=128, output_channels=128, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (4): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.2.4.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.2.4.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.2.4.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.2.4.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#             (5): LeakyReLU<>
#             >
#           (3): SequentialCell<
#             (0): Conv2d<input_channels=128, output_channels=128, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=128, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (1): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.3.1.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.3.1.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.3.1.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.3.1.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#             (2): LeakyReLU<>
#             (3): Conv2d<input_channels=128, output_channels=128, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (4): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.3.4.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.3.4.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.3.4.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.3.4.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#             (5): LeakyReLU<>
#             >
#           (4): SequentialCell<
#             (0): Conv2d<input_channels=128, output_channels=128, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=128, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (1): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.4.1.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.4.1.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.4.1.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.4.1.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#             (2): LeakyReLU<>
#             (3): Conv2d<input_channels=128, output_channels=128, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (4): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.4.4.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.4.4.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.4.4.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.4.4.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#             (5): LeakyReLU<>
#             >
#           (5): SequentialCell<
#             (0): Conv2d<input_channels=128, output_channels=128, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=128, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (1): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.5.1.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.5.1.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.5.1.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.5.1.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#             (2): LeakyReLU<>
#             (3): Conv2d<input_channels=128, output_channels=128, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (4): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage2.5.4.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage2.5.4.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage2.5.4.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage2.5.4.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#             (5): LeakyReLU<>
#             >
#           >
#         (stage3): SequentialCell<
#           (0): SequentialCell<
#             (0): Conv2d<input_channels=128, output_channels=128, kernel_size=(3, 3), stride=(2, 2), pad_mode=pad, padding=1, dilation=(1, 1), group=128, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (1): BatchNorm2d<num_features=128, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage3.0.1.gamma, shape=(128,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage3.0.1.beta, shape=(128,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage3.0.1.moving_mean, shape=(128,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage3.0.1.moving_variance, shape=(128,), dtype=Float32, requires_grad=False)>
#             (2): LeakyReLU<>
#             (3): Conv2d<input_channels=128, output_channels=256, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (4): BatchNorm2d<num_features=256, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage3.0.4.gamma, shape=(256,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage3.0.4.beta, shape=(256,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage3.0.4.moving_mean, shape=(256,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage3.0.4.moving_variance, shape=(256,), dtype=Float32, requires_grad=False)>
#             (5): LeakyReLU<>
#             >
#           (1): SequentialCell<
#             (0): Conv2d<input_channels=256, output_channels=256, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=256, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (1): BatchNorm2d<num_features=256, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage3.1.1.gamma, shape=(256,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage3.1.1.beta, shape=(256,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage3.1.1.moving_mean, shape=(256,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage3.1.1.moving_variance, shape=(256,), dtype=Float32, requires_grad=False)>
#             (2): LeakyReLU<>
#             (3): Conv2d<input_channels=256, output_channels=256, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=normal, bias_init=zeros, format=NCHW>
#             (4): BatchNorm2d<num_features=256, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=base.stage3.1.4.gamma, shape=(256,), dtype=Float32, requires_grad=True), beta=Parameter (name=base.stage3.1.4.beta, shape=(256,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=base.stage3.1.4.moving_mean, shape=(256,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=base.stage3.1.4.moving_variance, shape=(256,), dtype=Float32, requires_grad=False)>
#             (5): LeakyReLU<>
#             >
#           >
#         (fc): Dense<input_channels=256, output_channels=1000, has_bias=True>
#         >
#       (fpn): FPN<
#         (output1): ConvBNReLU<
#           (0): Conv2d<input_channels=64, output_channels=64, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=[[[[-0.03136497]]
#
#             [[ 0.11267858]]
#
#             [[ 0.05799849]]
#
#             ...
#
#             [[-0.05716274]]
#
#             [[ 0.08218437]]
#
#             [[-0.03581167]]]
#
#
#            [[[-0.05476637]]
#
#             [[ 0.01067402]]
#
#             [[-0.08976895]]
#
#             ...
#
#             [[-0.01822305]]
#
#             [[ 0.07950369]]
#
#             [[ 0.09018265]]]
#
#
#            [[[-0.12326197]]
#
#             [[ 0.00268683]]
#
#             [[-0.02064725]]
#
#             ...
#
#             [[-0.06453693]]
#
#             [[-0.10172431]]
#
#             [[ 0.09930394]]]
#
#
#            ...
#
#
#            [[[ 0.08605308]]
#
#             [[-0.00399486]]
#
#             [[ 0.00352386]]
#
#             ...
#
#             [[ 0.07184299]]
#
#             [[-0.04839179]]
#
#             [[-0.1149355 ]]]
#
#
#            [[[ 0.02208805]]
#
#             [[-0.0255789 ]]
#
#             [[ 0.11845011]]
#
#             ...
#
#             [[-0.03488137]]
#
#             [[ 0.04281771]]
#
#             [[-0.05733902]]]
#
#
#            [[[-0.10469259]]
#
#             [[ 0.12314545]]
#
#             [[-0.08594962]]
#
#             ...
#
#             [[ 0.10721489]]
#
#             [[-0.04200712]]
#
#             [[-0.00866577]]]], bias_init=zeros, format=NCHW>
#           (1): BatchNorm2d<num_features=64, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=network.fpn.output1.1.gamma, shape=(64,), dtype=Float32, requires_grad=True), beta=Parameter (name=network.fpn.output1.1.beta, shape=(64,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=network.fpn.output1.1.moving_mean, shape=(64,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=network.fpn.output1.1.moving_variance, shape=(64,), dtype=Float32, requires_grad=False)>
#           (2): LeakyReLU<>
#           >
#         (output2): ConvBNReLU<
#           (0): Conv2d<input_channels=128, output_channels=64, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=[[[[-0.08596961]]
#
#             [[-0.0739636 ]]
#
#             [[-0.04267538]]
#
#             ...
#
#             [[ 0.02008853]]
#
#             [[ 0.07034568]]
#
#             [[ 0.05478742]]]
#
#
#            [[[ 0.01469549]]
#
#             [[ 0.04069784]]
#
#             [[-0.02389624]]
#
#             ...
#
#             [[ 0.02323885]]
#
#             [[ 0.05027626]]
#
#             [[ 0.01742364]]]
#
#
#            [[[-0.01517786]]
#
#             [[ 0.08095416]]
#
#             [[ 0.00726797]]
#
#             ...
#
#             [[-0.02513566]]
#
#             [[ 0.01657823]]
#
#             [[ 0.01336316]]]
#
#
#            ...
#
#
#            [[[ 0.03566135]]
#
#             [[ 0.04531348]]
#
#             [[ 0.04949079]]
#
#             ...
#
#             [[-0.03371682]]
#
#             [[ 0.000424  ]]
#
#             [[-0.02851769]]]
#
#
#            [[[ 0.04543371]]
#
#             [[ 0.00775938]]
#
#             [[ 0.06661791]]
#
#             ...
#
#             [[-0.07466201]]
#
#             [[-0.01914584]]
#
#             [[-0.06116927]]]
#
#
#            [[[-0.02177542]]
#
#             [[ 0.0226597 ]]
#
#             [[ 0.00835048]]
#
#             ...
#
#             [[ 0.04686554]]
#
#             [[ 0.04667128]]
#
#             [[-0.03669081]]]], bias_init=zeros, format=NCHW>
#           (1): BatchNorm2d<num_features=64, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=network.fpn.output2.1.gamma, shape=(64,), dtype=Float32, requires_grad=True), beta=Parameter (name=network.fpn.output2.1.beta, shape=(64,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=network.fpn.output2.1.moving_mean, shape=(64,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=network.fpn.output2.1.moving_variance, shape=(64,), dtype=Float32, requires_grad=False)>
#           (2): LeakyReLU<>
#           >
#         (output3): ConvBNReLU<
#           (0): Conv2d<input_channels=256, output_channels=64, kernel_size=(1, 1), stride=(1, 1), pad_mode=pad, padding=0, dilation=(1, 1), group=1, has_bias=False, weight_init=[[[[-5.2326210e-02]]
#
#             [[-6.1070915e-02]]
#
#             [[-9.0686837e-03]]
#
#             ...
#
#             [[-9.2310561e-03]]
#
#             [[ 5.5730551e-02]]
#
#             [[-3.5283871e-02]]]
#
#
#            [[[-3.0407300e-02]]
#
#             [[-4.9888901e-02]]
#
#             [[ 1.3196284e-02]]
#
#             ...
#
#             [[-2.3686090e-03]]
#
#             [[ 2.1753272e-02]]
#
#             [[-8.1269778e-03]]]
#
#
#            [[[ 7.3404261e-03]]
#
#             [[-5.5244207e-02]]
#
#             [[ 2.4532935e-02]]
#
#             ...
#
#             [[ 9.9025043e-03]]
#
#             [[-5.7216376e-02]]
#
kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=1, has_bias=False, weight_init=[[[[-0.01310588  0.01081366  0.00990519]
#              [-0.03411529 -0.02195912 -0.00046628]
#              [-0.01113908 -0.01500359 -0.00452386]]
#
#             [[-0.01747383 -0.01271069  0.02280248]
#              [ 0.00085258  0.03107132  0.03738002]
#              [ 0.03517311 -0.02052408 -0.00225951]]
#
#             [[ 0.00292102  0.02934923  0.00491839]
#              [-0.02060704  0.00396159 -0.03797629]
#              [ 0.02784478  0.00549995  0.0126431 ]]
#
#             ...
#
#             [[-0.02326618  0.01398503  0.00450257]
#              [-0.0273387   0.02726342 -0.00389258]
#              [-0.02897959  0.02468183 -0.03054713]]
#
#             [[ 0.03900321 -0.00484918  0.01901852]
#              [-0.00400269 -0.02603645  0.0215095 ]
#              [-0.01755358  0.01520149 -0.02021894]]
#
#             [[-0.02157431 -0.0035462   0.02635328]
#              [ 0.00946942 -0.0362776   0.01948872]
#              [ 0.00664758  0.01029713 -0.01220182]]]
#
#
#            [[[ 0.00468014 -0.01067594 -0.03487453]
#              [ 0.02870252  0.01483556  0.01420325]
#              [-0.02552677  0.01363305 -0.02233078]]
#
#             [[ 0.01562789 -0.01387246 -0.02854052]
#              [ 0.03385536 -0.03294581  0.02181565]
#              [-0.03318536  0.0153933  -0.03246787]]
#
#             [[ 0.00073537 -0.02600036  0.03054846]
#              [-0.00820962 -0.04038114  0.0106801 ]
#              [-0.00457174  0.02997828 -0.00557132]]
#
#             ...
#
#             [[-0.00877764 -0.03134869 -0.01387925]
#              [ 0.02834783  0.02594983 -0.03930262]
#              [-0.02997695  0.0213251  -0.01368893]]
#
#             [[ 0.01196592  0.00522298  0.01267228]
#              [-0.03719195  0.0359266  -0.03991921]
#              [-0.04099729 -0.02282058  0.04112466]]
#
#             [[-0.0356223   0.03120835 -0.02840924]
#              [-0.03257472  0.02324753  0.02888989]
#              [ 0.02434857 -0.02158093  0.03165356]]]
#
#
#            [[[-0.03567621 -0.01316854 -0.00306807]
#              [-0.03602206  0.00665361  0.00494858]
#              [ 0.04101522  0.01013867 -0.00853786]]
#
#             [[ 0.02418207 -0.01375275  0.00273905]
#              [-0.0370442  -0.01477785  0.00234233]
#              [ 0.01685932 -0.03341394  0.02476556]]
#
#             [[ 0.03334658 -0.0182469   0.02211221]
#              [-0.02663762  0.00195132  0.02480295]
#              [-0.00945903 -0.03947498  0.00333061]]
#
#             ...
#
#             [[ 0.00417434  0.02709764  0.0117992 ]
#              [ 0.03537929  0.01674367 -0.00532415]
#              [-0.02419295 -0.04078994 -0.0341331 ]]
#
#             [[-0.02586035 -0.02362989  0.02017034]
#              [-0.00949535 -0.01462171 -0.0373027 ]
#              [ 0.00322171  0.00940907  0.03148812]]
#
#             [[ 0.00023684 -0.04102332 -0.03622677]
#              [-0.01908289 -0.03006787  0.02254895]
#              [-0.03267859 -0.02826804  0.01389895]]]
#
#
#            ...
#
#
#            [[[-0.02996971 -0.01047424 -0.00569118]
#              [ 0.01810948 -0.00033273  0.02085946]
#              [ 0.02843588 -0.01756545  0.02532632]]
#
#             [[-0.00070523 -0.03528865 -0.01691446]
#              [ 0.02524319 -0.00925683 -0.03389475]
#              [ 0.01152919  0.02919172 -0.03059525]]
#
#             [[ 0.00358378 -0.02435311 -0.01352004]
#              [-0.00717415 -0.04123151 -0.01202421]
#              [-0.01588293  0.01403073  0.03167522]]
#
#             ...
#
#             [[ 0.03935827 -0.03301637  0.00406489]
#              [ 0.00257324  0.0307227   0.02325727]
#              [-0.01774066  0.00183162 -0.01015214]]
#
#             [[-0.01223533  0.0192465   0.00828327]
#              [-0.02508942  0.01005782 -0.00302779]
#              [-0.01324664 -0.03612253  0.03572437]]
#
#             [[ 0.03014005 -0.01637311  0.0046952 ]
#              [ 0.03038963  0.00162053 -0.02984846]
#              [-0.00210934 -0.01550041 -0.00351475]]]
#
#
#            [[[ 0.02899884 -0.00759901  0.02494977]
#              [-0.02227955  0.00781087 -0.00616055]
#              [ 0.03942466 -0.0416033  -0.01136109]]
#
#             [[ 0.02611492 -0.00904121 -0.02354086]
#              [ 0.02943984  0.00764396  0.00472084]
#              [-0.00826397 -0.0285318   0.00629938]]
#
#             [[ 0.00044    -0.00815852 -0.03525976]
#              [ 0.01258005  0.01097805  0.00492298]
#              [-0.03070934 -0.01643016 -0.00251182]]
#
#             ...
#
#             [[-0.02156319 -0.03931933 -0.03528553]
#              [-0.03595618  0.01062621 -0.02976159]
#              [ 0.02881237  0.0410553  -0.00490068]]
#
#             [[ 0.00313651 -0.02000737  0.01296215]
#              [ 0.0345828  -0.02660109  0.03776541]
#              [-0.02322031 -0.01950552  0.03429754]]
#
#             [[ 0.00778133 -0.03902587  0.02524602]
#              [ 0.01183773  0.02025528 -0.02818737]
#              [ 0.03107771  0.02357158  0.03811855]]]
#
#
#            [[[-0.00760048  0.00152962  0.01681084]
#              [-0.03296755 -0.02413593 -0.01764559]
#              [ 0.03709297 -0.04155341  0.0411639 ]]
#
#             [[-0.00870131  0.0123575  -0.00743888]
#              [ 0.02367056  0.03754844 -0.00435206]
#              [-0.02665012 -0.02315983 -0.01951651]]
#
#             [[-0.02320348 -0.040564    0.03015993]
#              [ 0.0150779   0.00131281 -0.02942205]
#              [-0.03827366 -0.00961463 -0.04122348]]
#
#             ...
#
#             [[ 0.01437077  0.03979749  0.00098662]
#              [-0.01318483 -0.02812721  0.03361246]
#              [-0.03749357 -0.03583567 -0.03635149]]
#
#             [[-0.00279669  0.03593218  0.00464875]
#              [-0.01211111 -0.0217892   0.00120698]
#              [-0.00487391 -0.03387898 -0.04114186]]
#
#             [[ 0.00791954  0.02986556  0.00906981]
#              [-0.01447049 -0.02889842  0.0199209 ]
#              [ 0.01684634  0.02890897  0.04023894]]]], bias_init=zeros, format=NCHW>
#           (1): BatchNorm2d<num_features=64, eps=1e-05, momentum=0.09999999999999998, gamma=Parameter (name=network.fpn.merge2.1.gamma, shape=(64,), dtype=Float32, requires_grad=True), beta=Parameter (name=network.fpn.merge2.1.beta, shape=(64,), dtype=Float32, requires_grad=True), moving_mean=Parameter (name=network.fpn.merge2.1.moving_mean, shape=(64,), dtype=Float32, requires_grad=False), moving_variance=Parameter (name=network.fpn.merge2.1.moving_variance, shape=(64,), dtype=Float32, requires_grad=False)>
#           (2): LeakyReLU<>
#           >
#         >
#       (ssh1): SSH<
#         (conv3x3): ConvBN<
#           (0): Conv2d<input_channels=64, output_channels=32, kernel_size=(3, 3), stride=(1, 1), pad_mode=pad, padding=1, dilation=(1, 1), group=1, has_bias=False, weight_init=[[[[-3.23238708e-02 -1.96177326e-02 -1.30189070e-02]
#              [ 3.54190059e-02 -1.05580874e-03  3.72508503e-02]
#              [-3.04886419e-02 -8.35285056e-03  2.68576629e-02]]
#
#             ...
#
#             [[-1.82748511e-02  8.22947081e-03 -2.43752655e-02]
#              [ 3.28995958e-02 -3.02619226e-02  1.56858675e-02]
#              [-1.74876526e-02 -1.05167953e-02  3.99544369e-03]]
#
#             [[-6.04494801e-03  1.95101171e-03  1.49705568e-02]
#              [-1.69803295e-02  1.99011341e-02 -6.90086093e-03]
#              [-3.98503020e-02  2.88872626e-02 -1.82010606e-02]]
#
#             [[ 3.00198663e-02  2.03813240e-02 -7.77417142e-03]
#              [ 1.25238700e-02  4.09958437e-02 -1.60416458e-02]
#              [-4.13034437e-03 -2.92901546e-02  3.09474450e-02]]]
#
#
#            ...
#
#
#            [[[-3.19426134e-02 -8.95693153e-03  4.14835848e-02]
#              [ 3.95889580e-02 -2.27655657e-03 -4.83890809e-03]
#              [ 7.43445801e-03  1.34915356e-02 -1.95985902e-02]]
#
#             [[-2.74339411e-02  2.63972990e-02 -1.21584451e-02]
# ...
#             [[ 0.10206677]]
#
#             [[ 0.00399695]]
#
#             [[ 0.08732527]]
#
#             [[-0.11620615]]
#
#             [[ 0.10130894]]
#
#             [[-0.07338422]]
#
#             [[-0.09231371]]
#
#             [[ 0.09872713]]
#
#             [[-0.10682948]]
#
#             [[ 0.02677983]]
#
#             [[ 0.01100681]]
#
#             [[-0.12132595]]
#
#             [[ 0.06087784]]
#
#             [[-0.04363855]]
#
#             [[-0.11421496]]
#
#             [[-0.10303507]]
#
#             [[-0.05380174]]
#
#             [[ 0.03986758]]
#
#             [[ 0.05901287]]
#
#             [[ 0.09853642]]
#
#             [[ 0.01165175]]
#
#             [[-0.02254462]]
#
#             [[ 0.09492424]]
#
#             [[-0.02797688]]
#
#             [[-0.00570773]]
#
#             [[-0.02367667]]
#
#             [[ 0.04733118]]
#
#             [[ 0.0501971 ]]
#
#             [[ 0.01347846]]
#
#             [[ 0.03563077]]
#
#             [[-0.09113088]]
#
#             [[ 0.07627052]]
#
#             [[ 0.06175433]]
#
#             [[-0.10163226]]
#
#             [[ 0.02197796]]
#
#             [[-0.05042969]]
#
#             [[ 0.05667137]]
#
#             [[ 0.11937606]]
#
#             [[-0.10405646]]
#
#             [[ 0.0356474 ]]
#
#             [[ 0.07789201]]]
#
#
#            [[[-0.07342738]]
#
#             [[-0.07658599]]
#
#             [[ 0.01184597]]
#
#             [[-0.0818024 ]]
#
#             [[-0.01953278]]
#
#             [[-0.0276658 ]]
#
#             [[-0.00653234]]
#
#             [[ 0.08799778]]
#
#             [[ 0.1057347 ]]
#
#             [[ 0.09491479]]
#
#             [[-0.04746303]]
#
#             [[ 0.06431379]]
#
#             [[-0.03206751]]
#
#             [[ 0.10771161]]
#
#             [[-0.04770182]]
#
#             [[-0.07511391]]
#
#             [[ 0.08228513]]
#
#             [[-0.05129223]]
#
#             [[ 0.03876377]]
#
#             [[ 0.00450003]]
#
#             [[-0.07658106]]
#
#             [[ 0.04901382]]
#
#             [[ 0.02313844]]
#
#             [[-0.01868447]]
#
#             [[ 0.00211985]]
#
#             [[-0.11403055]]
#
#             [[-0.00938006]]
#
#             [[-0.08440918]]
#
#             [[-0.12498783]]
#
#             [[-0.07998161]]
#
#             [[ 0.01477067]]
#
#             [[ 0.00541093]]
#
#             [[-0.08859876]]
#
#             [[-0.123407  ]]
#
#             [[-0.02743082]]
#
#             [[-0.08168336]]
#
#             [[ 0.02379277]]
#
#             [[-0.00198291]]
#
#             [[ 0.03437313]]
#
#             [[-0.06697703]]
#
#             [[ 0.06273629]]
#
#             [[-0.11884708]]
#
#             [[-0.01449374]]
#
#             [[-0.01806301]]
#
#             [[ 0.10784499]]
#
#             [[ 0.02871769]]
#
#             [[ 0.09380561]]
#
#             [[ 0.03666148]]
#
#             [[-0.02335553]]
#
#             [[ 0.10300087]]
#
#             [[ 0.10727682]]
#
#             [[ 0.11906265]]
#
#             [[-0.0369576 ]]
#
#             [[-0.10238626]]
#
#             [[-0.09713667]]
#
#             [[-0.0176633 ]]
#
#             [[-0.09049416]]
#
#             [[ 0.10603427]]
#
#             [[-0.06044694]]
#
#             [[ 0.05657554]]
#
#             [[ 0.00643751]]
#
#             [[ 0.1034174 ]]
#
#             [[ 0.01687668]]
#
#             [[ 0.12128118]]]
#
#
#            [[[-0.10465018]]
#
#             [[ 0.04137226]]
#
#             [[ 0.02871008]]
#
#             [[ 0.04408861]]
#
#             [[-0.04569753]]
#
#             [[-0.10286768]]
#
#             [[-0.07143368]]
#
#             [[ 0.09029781]]
#
#             [[ 0.08220701]]
#
#             [[-0.06909885]]
#
#             [[-0.11788401]]
#
#             [[ 0.0408827 ]]
#
#             [[-0.07008236]]
#
#             [[-0.00172753]]
#
#             [[-0.01523919]]
#
#             [[ 0.04108904]]
#
#             [[-0.03706225]]
#
#             [[-0.01572955]]
#
#             [[ 0.08232275]]
#
#             [[-0.04651045]]
#
#             [[-0.07828254]]
#
#             [[-0.02915381]]
#
#             [[-0.05922602]]
#
#             [[ 0.10106028]]
#
#             [[-0.12230319]]
#
#             [[ 0.08114323]]
#
#             [[-0.06424982]]
#
#             [[-0.05692493]]
#
#             [[-0.09799464]]
#
#             [[ 0.00535691]]
#
#             [[-0.11359742]]
#
#             [[-0.01580256]]
#
#             [[ 0.05823968]]
#
#             [[ 0.05443152]]
#
#             [[-0.09196038]]
#
#             [[-0.04030427]]
#
#             [[ 0.07214313]]
#
#             [[-0.08881977]]
#
#             [[-0.07181456]]
#
#             [[-0.07838824]]
#
#             [[ 0.10646826]]
#
#             [[-0.11694592]]
#
#             [[-0.09755758]]
#
#             [[ 0.12196326]]
#
#             [[ 0.05485645]]
#
#             [[ 0.05243072]]
#
#             [[-0.05411016]]
#
#             [[ 0.03347715]]
#
#             [[-0.00971213]]
#
#             [[-0.04437888]]
#
#             [[-0.10741735]]
#
#             [[ 0.12399153]]
#
#             [[-0.10672759]]
#
#             [[ 0.0042752 ]]
#
#             [[ 0.00257857]]
#
#             [[ 0.05740612]]
#
#             [[-0.08013073]]
#
#             [[ 0.09356421]]
#
#             [[ 0.07167282]]
#
#             [[ 0.02039733]]
#
#             [[ 0.027545  ]]
#
#             [[-0.03854016]]
#
#             [[-0.10372098]]
#
#             [[-0.07012505]]]
#
#
#            [[[ 0.05768338]]
#
#             [[-0.11840018]]
#
#             [[-0.09258994]]
#
#             [[ 0.09258158]]
#
#             [[ 0.08054789]]
#
#             [[ 0.07365398]]
#
#             [[ 0.0104652 ]]
#
#             [[ 0.07826498]]
#
#             [[ 0.01287376]]
#
#             [[-0.01546954]]
#
#             [[ 0.11777766]]
#
#             [[ 0.12005596]]
#
#             [[-0.06999076]]
#
#             [[-0.05595121]]
#
#             [[-0.05488281]]
#
#             [[-0.12002736]]
#
#             [[ 0.04106962]]
#
#             [[ 0.0607038 ]]
#
#             [[-0.09460468]]
#
#             [[ 0.09973408]]
#
#             [[-0.0842943 ]]
#
#             [[ 0.03482461]]
#
#             [[ 0.07937609]]
#
#             [[-0.00370865]]
#
#             [[-0.07366523]]
#
#             [[-0.11131665]]
#
#             [[ 0.01804877]]
#
#             [[-0.02721989]]
#
#             [[-0.10135803]]
#
#             [[ 0.08941694]]
#
#             [[-0.11640904]]
#
#             [[ 0.069507  ]]
#
#             [[ 0.06711199]]
#
#             [[-0.12419552]]
#
#             [[-0.08869303]]
#
#             [[ 0.04693426]]
#
#             [[-0.01244352]]
#
#             [[ 0.02194765]]
#
#             [[-0.05560708]]
#
#             [[-0.06323257]]
#
#             [[ 0.01616281]]
#
#             [[-0.04649884]]
#
#             [[-0.12293606]]
#
#             [[-0.06191086]]
#
#             [[-0.06508635]]
#
#             [[-0.05921249]]
#
#             [[ 0.05368768]]
#
#             [[-0.10796905]]
#
#             [[-0.11485462]]
#
#             [[-0.01496728]]
#
#             [[-0.02947919]]
#
#             [[ 0.07259478]]
#
#             [[ 0.08447067]]
#
#             [[-0.00867409]]
#
#             [[-0.0727896 ]]
#
#             [[-0.05175861]]
#
#             [[ 0.06675438]]
#
#             [[-0.09795051]]
#
#             [[-0.00234696]]
#
#             [[ 0.10263179]]
#
#             [[-0.07507818]]
#
#             [[-0.12366974]]
#
#             [[-0.00342081]]
#
#             [[-0.04088119]]]], bias_init=[ 0.05382174  0.08447228 -0.06534094 -0.04706277 -0.11848809  0.02794306
#             0.01602952 -0.00290283], format=NCHW>
#           >
#         >
#       (landmarkhead): CellList<
#         (0): LandmarkHead<
#           (conv1x1): Conv2d<input_channels=64, output_channels=20, kernel_size=(1, 1), stride=(1, 1), pad_mode=same, padding=0, dilation=(1, 1), group=1, has_bias=True, weight_init=[[[[-0.0653588 ]]
#
#             [[ 0.02325419]]
#
#             [[ 0.02899218]]
#
#             ...
#
#             [[-0.00811465]]
#
#             [[-0.05752086]]
#
#             [[-0.11302832]]]
#
#
#            [[[-0.07252625]]
#
#             [[-0.10044938]]
#
#             [[ 0.09326287]]
#
#             ...
#
#             [[-0.11281712]]
#
#             [[-0.08194516]]
#
#             [[-0.03124272]]]
#
#
#            [[[-0.11106289]]
#
#             [[-0.09137164]]
#
#             [[ 0.07008419]]
#
#             ...
#
#             [[-0.00427137]]
#
#             [[-0.01607775]]
#
#             [[-0.05605372]]]
#
#
#            ...
#
#
#            [[[-0.01259071]]
#
#             [[ 0.0029925 ]]
#
#             [[ 0.11023385]]
#
#             ...
#
#             [[-0.02408899]]
#
#             [[ 0.0912229 ]]
#
#             [[ 0.05574048]]]
#
#
#            [[[ 0.05445006]]
#
#             [[ 0.07536841]]
#
#             [[-0.10625771]]
#
#             ...
#
#             [[-0.0211121 ]]
#
#             [[ 0.12216372]]
#
#             [[-0.04837928]]]
#
#
#            [[[ 0.07165819]]
#
#             [[-0.02592759]]
#
#             [[ 0.03647464]]
#
#             ...
#
#             [[-0.0245426 ]]
#
#             [[-0.04654476]]
#
#             [[ 0.01613258]]]], bias_init=[ 0.05414535 -0.02863894  0.11415346  0.03286158 -0.09530407  0.09206541
#             0.04017619 -0.02611531  0.08966954  0.01639848 -0.06596173 -0.07224327
#             0.07476466  0.02277052  0.10175966 -0.08947156 -0.08445574  0.06374609
#            -0.01066985 -0.10125124], format=NCHW>
#           >
#         (1): LandmarkHead<
#           (conv1x1): Conv2d<input_channels=64, output_channels=20, kernel_size=(1, 1), stride=(1, 1), pad_mode=same, padding=0, dilation=(1, 1), group=1, has_bias=True, weight_init=[[[[ 0.00358068]]
#
#             [[ 0.12426128]]
#
#             [[-0.06585716]]
#
#             ...
#
#             [[-0.09734076]]
#
#             [[-0.04321113]]
#
#             [[-0.00961618]]]
#
#
#            [[[-0.10277773]]
#
#             [[-0.09220212]]
#
#             [[-0.11758328]]
#
#             ...
#
#             [[-0.08050378]]
#
#             [[-0.08951245]]
#
#             [[-0.12063331]]]
#
#
#            [[[-0.0449147 ]]
#
#             [[ 0.03370849]]
#
#             [[-0.07513755]]
#
#             ...
#
#             [[-0.01857302]]
#
#             [[-0.1007526 ]]
#
#             [[ 0.12078415]]]
#
#
#            ...
#
#
#            [[[-0.0597114 ]]
#
#             [[ 0.0085814 ]]
#
#             [[ 0.10340444]]
#
#             ...
#
#             [[-0.02819916]]
#
#             [[-0.12492356]]
#
#             [[-0.08493023]]]
#
#
#            [[[ 0.10049584]]
#
#             [[ 0.08459831]]
#
#             [[ 0.10932685]]
#
#             ...
#
#             [[ 0.11419805]]
#
#             [[-0.07410893]]
#
#             [[-0.05809066]]]
#
#
#            [[[-0.11180259]]
#
#             [[-0.01826129]]
#
#             [[-0.0381434 ]]
#
#             ...
#
#             [[-0.08247306]]
#
#             [[-0.0014336 ]]
#
#             [[-0.03655935]]]], bias_init=[-0.12344098 -0.04067947 -0.0036378  -0.07383668 -0.06831656 -0.09884556
#            -0.05301439  0.03157887  0.05649547  0.10945679  0.08885825 -0.09810432
#             0.06184784  0.00966601  0.01002616 -0.04747055 -0.00793113  0.0543037
#             0.06566436 -0.01242254], format=NCHW>
#           >
#         (2): LandmarkHead<
#           (conv1x1): Conv2d<input_channels=64, output_channels=20, kernel_size=(1, 1), stride=(1, 1), pad_mode=same, padding=0, dilation=(1, 1), group=1, has_bias=True, weight_init=[[[[ 0.0513016 ]]
#
#             [[ 0.05233982]]
#
#             [[ 0.10302562]]
#
#             ...
#
#             [[ 0.01446032]]
#
#             [[-0.04745722]]
#
#             [[-0.02093972]]]
#
#
#            [[[-0.08234599]]
#
#             [[-0.0007145 ]]
#
#             [[ 0.09202049]]
#
#             ...
#
#             [[ 0.04523911]]
#
#             [[-0.09334278]]
#
#             [[-0.00420657]]]
#
#
#            [[[-0.07493368]]
#
#             [[-0.10226868]]
#
#             [[ 0.03668706]]
#
#             ...
#
#             [[ 0.09010993]]
#
#             [[ 0.00208953]]
#
#             [[-0.03266313]]]
#
#
#            ...
#
#
#            [[[ 0.10775886]]
#
#             [[ 0.05248325]]
#
#             [[ 0.05735843]]
#
#             ...
#
#             [[ 0.01156745]]
#
#             [[ 0.08356827]]
#
#             [[ 0.08953626]]]
#
#
#            [[[ 0.0153541 ]]
#
#             [[-0.00473282]]
#
#             [[ 0.01701587]]
#
#             ...
#
#             [[-0.1131289 ]]
#
#             [[ 0.08883651]]
#
#             [[-0.09303115]]]
#
#
#            [[[ 0.11693742]]
#
#             [[-0.01664815]]
#
#             [[ 0.05949557]]
#
#             ...
#
#             [[ 0.09185981]]
#
#             [[ 0.07541189]]
#
#             [[ 0.11810076]]]], bias_init=[ 0.09505635 -0.00851724 -0.1151537  -0.03611372 -0.0938806   0.07582618
#             0.08996104 -0.02302789 -0.09152261  0.06597113 -0.03550252  0.00417393
#            -0.12098659  0.07715964  0.11603611  0.01638712 -0.07495493  0.02297291
#             0.1072472  -0.03611465], format=NCHW>
#           >
#         >
#       >
#     (multibox_loss): MultiBoxLoss<
#       (cross_entropy): SoftmaxCrossEntropyWithLogits<>
#       >
#     >
#   (optimizer): SGD<
#     (learning_rate): _IteratorLearningRate<>
#     >
#   >

# %%
cfg['val_model'] = 'pretrained/RetinaFace_MobileNet025.ckpt'
assert cfg['val_model'] is not None, 'val_model is None.'
param_dict = load_checkpoint(cfg['val_model'])
print('Load trained model done. {}'.format(cfg['val_model']))
network.init_parameters_data()
load_param_into_net(network, param_dict)
# Out:
# [WARNING] ME(8443:140174223581376,MainProcess):2024-04-18-00:27:41.749.247 [mindspore/train/serialization.py:734] For 'load_param_into_net', remove parameter prefix name: network., continue to load.
# Load trained model done. pretrained/RetinaFace_MobileNet025.ckpt
# []

# %%
testset_folder = cfg['val_dataset_folder']
testset_label_path = cfg['val_dataset_folder'] + "label.txt"
with open(testset_label_path, 'r') as f:
    _test_dataset = f.readlines()
    test_dataset = []
    for im_path in _test_dataset:
        if im_path.startswith('# '):
            test_dataset.append(im_path[2:-1])

num_images = len(test_dataset)
print(num_images)
# Out:
# 3226

# %%
from mindface.detection.runner import DetectionEngine, Timer
import argparse
import os
import numpy as np
import cv2

from mindspore import Tensor, context
from mindspore.train.serialization import load_checkpoint, load_param_into_net
from mindspore import ops

from utils import prior_box
from models import RetinaFace, resnet50, mobilenet025
from runner import DetectionEngine, Timer, read_yaml
detection = DetectionEngine(nms_thresh=0.4, conf_thresh=0.02, iou_thresh=0.5, var=[0.1,0.2])

# %%
# 初始化计时器，forward_time表示网络推理的时间，misc表示后处理的时间。
timers = {'forward_time': Timer(), 'misc': Timer()}

if cfg['val_origin_size']:
    h_max, w_max = 0, 0
    for img_name in test_dataset:
        image_path = os.path.join(testset_folder, 'images', img_name)
        _img = cv2.imread(image_path, cv2.IMREAD_COLOR)
        if _img.shape[0] > h_max:
            h_max = _img.shape[0]
        if _img.shape[1] > w_max:
            w_max = _img.shape[1]

    h_max = (int(h_max / 32) + 1) * 32
    w_max = (int(w_max / 32) + 1) * 32

    priors = prior_box(image_sizes=(h_max, w_max),
                        min_sizes=[[16, 32], [64, 128], [256, 512]],
                        steps=[8, 16, 32],
                        clip=False)
else:
    target_size = 1600
    max_size = 2160
    priors = prior_box(image_sizes=(max_size, max_size),
                        min_sizes=[[16, 32], [64, 128], [256, 512]],
                        steps=[8, 16, 32],
                        clip=False)

# %%
print('Predict box starting')
ave_time = 0
ave_forward_pass_time = 0
ave_misc = 0
for i, img_name in enumerate(test_dataset):
    image_path = os.path.join(testset_folder, 'images', img_name)

    img_raw = cv2.imread(image_path, cv2.IMREAD_COLOR)
    img = np.float32(img_raw)

    # testing scale
    if cfg['val_origin_size']:
        resize = 1
        assert img.shape[0] <= h_max and img.shape[1] <= w_max
        image_t = np.empty((h_max, w_max, 3), dtype=img.dtype)
        image_t[:, :] = (104.0, 117.0, 123.0)
        image_t[0:img.shape[0], 0:img.shape[1]] = img
        img = image_t
    else:
        im_size_min = np.min(img.shape[0:2])
        im_size_max = np.max(img.shape[0:2])
        resize = float(target_size) / float(im_size_min)
        # prevent bigger axis from being more than max_size:
        if np.round(resize * im_size_max) > max_size:
            resize = float(max_size) / float(im_size_max)

        img = cv2.resize(img, None, None, fx=resize, fy=resize, interpolation=cv2.INTER_LINEAR)

        assert img.shape[0] <= max_size and img.shape[1] <= max_size
        image_t = np.empty((max_size, max_size, 3), dtype=img.dtype)
        image_t[:, :] = (104.0, 117.0, 123.0)
        image_t[0:img.shape[0], 0:img.shape[1]] = img
        img = image_t

    scale = np.array([img.shape[1], img.shape[0], img.shape[1], img.shape[0]], dtype=img.dtype)
    img -= (104, 117, 123)
    img = img.transpose(2, 0, 1)
    img = np.expand_dims(img, 0)
    img = Tensor(img)

    timers['forward_time'].start()
    boxes, confs, _ = network(img)
    timers['forward_time'].end()
    timers['misc'].start()
    print(resize)
    detection.eval(boxes, confs, resize, scale, img_name, priors)
    timers['misc'].end()

    ave_time = ave_time + timers['forward_time'].diff + timers['misc'].diff
    ave_forward_pass_time = ave_forward_pass_time + timers['forward_time'].diff
    ave_misc = ave_misc + timers['misc'].diff
    print('im_detect: {:d}/{:d} forward_pass_time: {:.4f}s misc: {:.4f}s sum_time: {:.4f}s'.format(i + 1, num_images,
                                                                                    timers['forward_time'].diff,
                                                                                    timers['misc'].diff,
                                                                                    timers['forward_time'].diff + timers['misc'].diff))
# Out:
# Predict box starting
# 2.109375
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_8443/1744991492.py in <module>
#      44     timers['misc'].start()
#      45     print(resize)
# ---> 46     detection.eval(boxes, confs, resize, scale, img_name, priors)
#      47     timers['misc'].end()
#      48
#
# /jupyter/mindface/mindface/detection/runner/engine.py in eval(self, boxes, confs, resize, scale, image_path, priors)
#     186             return
#     187
# --> 188         for i, size in enumerate(resize):
#     189             boxes_1 = boxes[i].asnumpy()
#     190             boxes_1 = decode_bbox(boxes_1, priors, self.var)
#
# TypeError: 'float' object is not iterable
